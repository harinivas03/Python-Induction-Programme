# %% [markdown]
# <a href="https://colab.research.google.com/github/harinivas03/Python-Induction-Programme/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sb
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Passengers.csv")

# %%
df.head(31)
# Out:
#       data_dte  Year  Month  usg_apt_id usg_apt  usg_wac  fg_apt_id fg_apt  \
# 0   05/01/2014  2014      5       14492     RDU     36.0    11032.0    CUN
# 1   06/01/2007  2007      6       13204     MCO     33.0    16085.0    YHZ
# 2   12/01/2005  2005     12       11433     DTW     43.0    10411.0    AUA
# 3   04/01/2003  2003      4       13487     MSP     63.0    16304.0    ZIH
# 4   12/01/2005  2005     12       12016     GUM      5.0    11138.0    CRK
# 5   03/01/2007  2007      3       14843     SJU      3.0    15084.0    SXM
# 6   03/01/2001  2001      3       14986     SRQ     33.0    13252.0    MEX
# 7   04/01/2007  2007      4       14027     PBI     33.0    11760.0    FRA
# 8   09/01/2005  2005      9       10559     BFI     93.0    15999.0    YAZ
# 9   08/01/2004  2004      8       10821     BWI     35.0    10150.0    ACC
# 10  06/01/2008  2008      6       13303     MIA     33.0    15627.0    VRA
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 94649 entries, 0 to 94648
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   data_dte      94649 non-null  object
#  1   Year          94649 non-null  int64
#  2   Month         94649 non-null  int64
#  3   usg_apt_id    94649 non-null  int64
#  4   usg_apt       94648 non-null  object
#  5   usg_wac       94648 non-null  float64
#  6   fg_apt_id     94648 non-null  float64
#  7   fg_apt        94648 non-null  object
#  8   fg_wac        94648 non-null  float64
#  9   airlineid     94648 non-null  float64
#  10  carrier       93882 non-null  object
#  11  carriergroup  94648 non-null  float64
#  12  type          94648 non-null  object
#  13  Scheduled     94648 non-null  float64
#  14  Charter       94648 non-null  float64
#  15  Total         94648 non-null  float64
# dtypes: float64(8), int64(3), object(5)
# memory usage: 11.6+ MB

# %%
df.shape
# Out:
# (94649, 16)

# %%
df.describe()
# Out:
#                Year         Month    usg_apt_id       usg_wac     fg_apt_id  \
# count  94649.000000  94649.000000  94649.000000  94648.000000  94648.000000
# mean    2001.228592      6.127091  12821.256199     42.330414  13526.861149
# std        6.989301      3.507882   3144.435685     25.455108   2027.861806
# min     1990.000000      1.000000    134.000000      1.000000  10125.000000
# 25%     1995.000000      3.000000  11433.000000     22.000000  11628.000000
# 50%     2001.000000      6.000000  12892.000000     33.000000  13605.000000
# 75%     2007.000000      9.000000  13930.000000     63.000000  15513.000000
# max     2015.000000     12.000000  99999.000000     93.000000  16575.000000
#
#              fg_wac     airlineid  carriergroup  Scheduled       Charter  \
# count  94648.000000  94648.000000  94648.000000    94648.0  94648.000000
# mean     429.527544  20214.223132      0.622876        0.0   1094.994538
# ...

# %%
df.columns
# Out:
# Index(['data_dte', 'Year', 'Month', 'usg_apt_id', 'usg_apt', 'usg_wac',
#        'fg_apt_id', 'fg_apt', 'fg_wac', 'airlineid', 'carrier', 'carriergroup',
#        'type', 'Scheduled', 'Charter', 'Total'],
#       dtype='object')

# %%
df.nunique()
# Out:
# data_dte         280
# Year              25
# Month             12
# usg_apt_id       664
# usg_apt          667
# usg_wac           54
# fg_apt_id        943
# fg_apt           944
# fg_wac           179
# airlineid        321
# carrier          344
# carriergroup       2
# type               1
# Scheduled          1
# Charter         7673
# Total           7673
# dtype: int64

# %%
df['airlineid'].unique
# Out:
# <bound method Series.unique of 0        19534.0
# 1        20364.0
# 2        20344.0
# 3        20204.0
# 4        20312.0
#           ...
# 94644    19559.0
# 94645    20029.0
# 94646    20204.0
# 94647    19954.0
# 94648        NaN
# Name: airlineid, Length: 94649, dtype: float64>

# %%
df.tail()
# Out:
#          data_dte  Year  Month  usg_apt_id usg_apt  usg_wac  fg_apt_id fg_apt  \
# 94644  11/01/1992  1992     11       12889     LAS     85.0    13252.0    MEX
# 94645  10/01/1992  1992     10       12265     IAG     22.0    11032.0    CUN
# 94646  01/01/1999  1999      1       13487     MSP     63.0    13180.0    MBJ
# 94647  12/01/1993  1993     12       12173     HNL      2.0    13853.0    OKJ
# 94648  03/01/1997  1997      3         134     NaN      NaN        NaN    NaN
#
#        fg_wac  airlineid carrier  carriergroup        type  Scheduled  \
# 94644   148.0    19559.0      MX           0.0  Passengers        0.0
# 94645   148.0    20029.0     TEQ           0.0  Passengers        0.0
# 94646   243.0    20204.0      MG           1.0  Passengers        0.0
# 94647   736.0    19954.0      JZ           0.0  Passengers        0.0
# 94648     NaN        NaN     NaN           NaN         NaN        NaN
#
#        Charter   Total
# 94644   3799.0  3799.0
# 94645    835.0   835.0
# ...

# %%
df.isnull().sum()
# Out:
# data_dte          0
# Year              0
# Month             0
# usg_apt_id        0
# usg_apt           1
# usg_wac           1
# fg_apt_id         1
# fg_apt            1
# fg_wac            1
# airlineid         1
# carrier         767
# carriergroup      1
# type              1
# Scheduled         1
# Charter           1
# Total             1
# dtype: int64

# %%
a = df.drop(['type'],axis=1)
a
# Out:
#          data_dte  Year  Month  usg_apt_id usg_apt  usg_wac  fg_apt_id fg_apt  \
# 0      05/01/2014  2014      5       14492     RDU     36.0    11032.0    CUN
# 1      06/01/2007  2007      6       13204     MCO     33.0    16085.0    YHZ
# 2      12/01/2005  2005     12       11433     DTW     43.0    10411.0    AUA
# 3      04/01/2003  2003      4       13487     MSP     63.0    16304.0    ZIH
# 4      12/01/2005  2005     12       12016     GUM      5.0    11138.0    CRK
# ...           ...   ...    ...         ...     ...      ...        ...    ...
# 94644  11/01/1992  1992     11       12889     LAS     85.0    13252.0    MEX
# 94645  10/01/1992  1992     10       12265     IAG     22.0    11032.0    CUN
# 94646  01/01/1999  1999      1       13487     MSP     63.0    13180.0    MBJ
# 94647  12/01/1993  1993     12       12173     HNL      2.0    13853.0    OKJ
# 94648  03/01/1997  1997      3         134     NaN      NaN        NaN    NaN
#
# ...

# %%
h = df.head(99)
h
# Out:
#       data_dte  Year  Month  usg_apt_id usg_apt  usg_wac  fg_apt_id fg_apt  \
# 0   05/01/2014  2014      5       14492     RDU     36.0    11032.0    CUN
# 1   06/01/2007  2007      6       13204     MCO     33.0    16085.0    YHZ
# 2   12/01/2005  2005     12       11433     DTW     43.0    10411.0    AUA
# 3   04/01/2003  2003      4       13487     MSP     63.0    16304.0    ZIH
# 4   12/01/2005  2005     12       12016     GUM      5.0    11138.0    CRK
# ..         ...   ...    ...         ...     ...      ...        ...    ...
# 94  07/01/2003  2003      7       13303     MIA     33.0    13605.0    NAS
# 95  02/01/2008  2008      2       13303     MIA     33.0    10911.0    CCS
# 96  06/01/2003  2003      6       11433     DTW     43.0    13180.0    MBJ
# 97  06/01/2004  2004      6       10529     BDL     11.0    11032.0    CUN
# 98  08/01/2008  2008      8       11433     DTW     43.0    16271.0    YYZ
#
# ...

# %%
plt.scatter(h.airlineid,h.Charter,color = "darkblue")
plt.xlabel('airlineid')
plt.ylabel('Charter')
# Out:
# Text(0, 0.5, 'Charter')

# %%
plt.plot(h.usg_apt_id,h.usg_wac)
plt.xlabel('usg_apt_id')
plt.ylabel('usg_wac')
# Out:
# Text(0, 0.5, 'usg_wac')

# %%
plt.pie(df.fg_apt_id)
plt.xlabel('fg_apt')
# Out:
# Text(0.5, 0, 'fg_apt')

# %%
plt.stem(h.usg_apt_id)
plt.xlabel('usg_wac')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   """Entry point for launching an IPython kernel.
# Text(0.5, 0, 'usg_wac')

# %%
plt.hist(h.usg_apt_id,color = "red")
plt.xlabel('usg_apt_id')
# Out:
# Text(0.5, 0, 'usg_apt_id')

# %%
plt.barh(h.usg_apt_id,h.usg_wac,color = "pink")
plt.xlabel('usg_apt_id')
plt.ylabel('usg_wac')
# Out:
# Text(0, 0.5, 'usg_wac')

# %%
plt.hist(h.usg_apt_id,color = "red")
plt.xlabel('usg_apt_id')
# Out:
# Text(0.5, 0, 'usg_apt_id')

# %%
plt.pie(h.usg_apt_id)
plt.xlabel('usg_wac')
# Out:
# Text(0.5, 0, 'usg_wac')

# %%
plt.stem(h.usg_apt_id)
plt.xlabel('usg_wac')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   """Entry point for launching an IPython kernel.
# Text(0.5, 0, 'usg_wac')

# %%
plt.polar(h.usg_apt_id)
plt.xlabel('usg_wac')
# Out:
# Text(0.5, 0, 'usg_wac')
